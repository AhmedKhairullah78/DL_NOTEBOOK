# %%
import cv2
import torch

model = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='yolov5_ws.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\DELL/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements:  Command 'pip install "gitpython" "tqdm>=4.64.0"  ' returned non-zero exit status 1.
# YOLOv5  2022-11-23 Python-3.8.8 torch-1.13.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# rom sklearn.pipeline import Pipeline
#
# pipe = Pipeline([('vectorizer', cv), ('multinomialNB', model)])
# pipe.fit(X_train, y_train)

# %%
import cv2

cap = cv2.VideoCapture('http://192.168.1.7:8080/video')

import cv2
import numpy as np
import requests
import io

ip = input("Enter the ipv4 address for your ip webcam: ")
url = ip + "/shot.jpg"
while True:

    img_request = requests.get(url)
    img_arrint = np.array(bytearray(img_request.content), dtype=np.uint8)
    img = cv2.imdecode(img_arrint, -1)
    
    results = model(img)
    ss=str(results)
    print(ss[18:])
    
    
    cv2.imshow("video-stream", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# Enter the ipv4 address for your ip webcam: http://192.168.1.7:8080
# 20 (no detections)
# Speed: 2.9ms pre-process, 125.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 167.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 124.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 182.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 167.9ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 112.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 3 pistols
# Speed: 2.9ms pre-process, 105.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 152.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 135.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.9ms pre-process, 127.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 137.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 139.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 108.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 163.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 165.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 4.0ms pre-process, 128.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.9ms pre-process, 109.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 5.0ms pre-process, 166.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 178.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 8.9ms pre-process, 181.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 140.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 160.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 107.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.9ms pre-process, 125.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 173.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 165.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 205.4ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.9ms pre-process, 163.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.9ms pre-process, 129.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 166.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 116.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 138.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 115.9ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.9ms pre-process, 119.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 141.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 132.8ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 139.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.9ms pre-process, 105.9ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 2.0ms pre-process, 127.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 4.9ms pre-process, 186.5ms inference, 2.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 190.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 173.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 187.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.2ms pre-process, 181.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 166.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.9ms pre-process, 173.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 164.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 176.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 161.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 169.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 161.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 161.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 5.0ms pre-process, 159.8ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 193.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.0ms pre-process, 183.7ms inference, 2.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 180.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 3.0ms pre-process, 205.4ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 3 pistols
# Speed: 3.0ms pre-process, 165.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 3 pistols
# Speed: 2.0ms pre-process, 162.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 4.0ms pre-process, 176.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 181.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.0ms pre-process, 207.4ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 202.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 225.4ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 6.0ms pre-process, 201.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 192.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 176.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 193.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 6.0ms pre-process, 197.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 201.4ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 7.0ms pre-process, 197.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 167.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 2.0ms pre-process, 169.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 5.0ms pre-process, 172.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 5.0ms pre-process, 178.8ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.0ms pre-process, 183.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 201.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 178.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 177.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 174.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 173.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 178.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 184.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 167.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 170.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 5.0ms pre-process, 192.6ms inference, 2.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 169.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 156.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 160.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 183.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.9ms pre-process, 176.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 11.0ms pre-process, 168.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 161.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 183.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 142.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 165.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 3.0ms pre-process, 172.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 179.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 8.9ms pre-process, 214.4ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 2 pistols
# Speed: 2.9ms pre-process, 114.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 115.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 151.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 181.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 195.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 155.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.0ms pre-process, 158.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 171.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 176.5ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 171.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 131.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 173.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 155.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 165.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 111.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.9ms pre-process, 131.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 188.5ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 159.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 152.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 136.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 151.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 147.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 164.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 106.7ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 124.7ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 5.0ms pre-process, 163.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 134.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 1 pistol
# Speed: 4.0ms pre-process, 138.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 2.0ms pre-process, 150.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 4.0ms pre-process, 141.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)
# 20 (no detections)
# Speed: 3.0ms pre-process, 140.6ms inference, 0.0ms NMS per image at shape (1, 3, 384, 640)

# %%
import cv2
import datetime
cap = cv2.VideoCapture('http://192.168.1.6:8080/video')
#cap = cv2.VideoCapture('rtsp://192.168.1.6:8080/1')

fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('out.avi',fourcc,20.0,(640,480))
while(True):
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    #frame=cv2.flip(frame,0)
    
    results = model(frame)
    #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    out.write(frame) 
    #print(results)
    cv2.imshow('frame',frame)
    ss=str(results)
    print(ss[18:27])
    if cv2.waitKey(1)==ord('q'):
        break
        
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('data/haarcascades/haarcascade_eye.xml')

video_capture = cv2.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,
                                         scaleFactor=1.1,
                                         minNeighbors=5,
                                         minSize=(60, 60),
                                         flags=cv2.CASCADE_SCALE_IMAGE)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h),(0,255,0), 2)
        cv2.putText(frame,'Face',(x,y-4),cv2.FONT_HERSHEY_COMPLEX,0.8,(255,255,255),2)
        # Display the resulting frame
        eye=eye_cascade.detectMultiScale(gray,2.3,4)
        for(ex,ey,ew,eh)in eye:
            cv2.rectangle(frame,(ex,ey),(ex+ew,ey+eh),(0,255,0),5)
            cv2.putText(frame,'Eye',(ex,ey-3),cv2.FONT_HERSHEY_COMPLEX,0.8,(255,255,255),2)
        
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch

model1 = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\DELL/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements:  Command 'pip install "gitpython" "tqdm>=4.64.0"  ' returned non-zero exit status 1.
# YOLOv5  2022-11-23 Python-3.8.8 torch-1.13.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...

# %%
import cv2

cap = cv2.VideoCapture('http://192.168.1.7:8080/video')

import cv2
import numpy as np
import requests
import io

ip = input("Enter the ipv4 address for your ip webcam: ")
url = ip + "/shot.jpg"
cap.set(3,100)
cap.set(4,100)
while True:

    img_request = requests.get(url)
    img_arrint = np.array(bytearray(img_request.content), dtype=np.uint8)
    img = cv2.imdecode(img_arrint, -1)
    
    results = model1(img)
    ss=str(results)
    print(ss[18:35])
    
    
    cv2.imshow("video-stream", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# Enter the ipv4 address for your ip webcam: http://192.168.1.7:8080
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 2 fires
# Speed:
# 20 1 fire
# Speed:
# 20 3 fires
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 2 fires
# Speed:
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 2 fires
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 1 fire
# Speed:
# 20 2 fires
# Speed:
# 20 (no detections
# 20 (no detections
# 20 2 fires
# Speed:
# 20 4 fires
# Speed:
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 (no detections
# 20 2 fires
# Speed:
# 20 3 fires
# Speed:
# 20 3 fires
# Speed:
# 20 2 fires
# Speed:
# 20 2 fires
# Speed:
# 20 3 fires
# Speed:
# 20 2 fires
# Speed:
# 20 2 fires
# Speed:
# 20 3 fires
# Speed:
# 20 2 fires
# Speed:
# 20 2 fires
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:
# 20 (no detections
# 20 1 fire
# Speed:

# %%
import cv2
import torch

model1 = torch.hub.load('ultralytics/yolov5', 'custom', 
 path='best _weapon.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\DELL/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirements "gitpython" "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements:  Command 'pip install "gitpython" "tqdm>=4.64.0"  ' returned non-zero exit status 1.
# YOLOv5  2022-11-23 Python-3.8.8 torch-1.13.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# Adding AutoShape...

# %%
video_capture = cv2.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    
    
    results = model(frame)
    ss=str(results)
    print(ss[18:35])
        
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  (no detections)
#
#  1 pistol
# Speed:
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 knife
# Speed: 3
#  (no detections)
#
#  1 knife
# Speed: 4
#  1 knife
# Speed: 3
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 knife
# Speed: 4
#  1 knife
# Speed: 4
#  1 knife
# Speed: 3
#  1 knife
# Speed: 4
#  1 knife
# Speed: 3
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 knife
# Speed: 3
#  1 knife
# Speed: 4
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  1 knife
# Speed: 4
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 knife
# Speed: 2
#  (no detections)
#
#  1 knife, 1 pisto
#  1 knife
# Speed: 6
#  1 knife
# Speed: 3
#  (no detections)
#
#  1 knife
# Speed: 5
#  1 pistol
# Speed:
#  2 pistols
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  2 pistols
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  1 knife
# Speed: 3
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  (no detections)
#
#  1 knife
# Speed: 4
#  1 pistol
# Speed:
#  1 pistol
# Speed:
#  (no detections)
#
#  1 pistol
# Speed:
#  (no detections)
#
#  (no detections)
#
#  (no detections)
